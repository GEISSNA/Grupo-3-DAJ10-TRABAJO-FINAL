# %% [markdown]
# <a href="https://colab.research.google.com/github/GEISSNA/Grupo-3-DAJ10-TRABAJO-FINAL/blob/main/Exploracion/An%C3%A1lisis%20Estad%C3%ADstico%20Descriptivo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ANÁLISIS EXPLORATORIO DE DATOS RSM**
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importación de datos desde archivo csv almacenado en repositorio de Github

# %%
url = "https://raw.githubusercontent.com/GEISSNA/Grupo-3-DAJ10-TRABAJO-FINAL/main/Exploracion/consolidado.csv"
data = pd.read_csv(url)

# %% [markdown]
# **METRICAS DE VENTAS**

# %% [markdown]
# **Ventas totales**

# %%
total = data['Venta Total'].sum()
print(total)
# Out:
# 4600795.36

# %%
#Obtener un resumen estadistico de la columna numerica
describe = data['Venta Total'].describe()
print(describe)
# Out:
# count     1000.000000
# mean      4600.795360
# std       3886.511139
# min         36.840000
# 25%       1477.990000
# 50%       3556.480000
# 75%       6937.800000
# max      17767.710000
# Name: Venta Total, dtype: float64

# %% [markdown]
# **Número de ventas por Región**

# %%
VxRegion = data.groupby('Region')['Venta Total'].count()
print(VxRegion)
# Out:
# Region
# Este     258
# Norte    240
# Oeste    259
# Sur      243
# Name: Venta Total, dtype: int64

# %%
#funcion que muestra un grafico rapido para las categorias
BarRegion = VxRegion.plot(kind='bar')

# %% [markdown]
# **Cantidad de Productos vendidos**

# %%
ProdVend = data['Cantidad'].sum()
print(ProdVend)
# Out:
# 4936

# %% [markdown]
# **Ventas por Categoría de producto**

# %%
VentasxCat = data.groupby('Categoria')['Venta Total'].sum()
print(VentasxCat)
# Out:
# Categoria
# Electrónica    1159376.30
# Hogar          1479785.05
# Juguetería     1326233.65
# Periféricos     635400.36
# Name: Venta Total, dtype: float64

# %%
barVxR = VentasxCat.plot(kind='bar')

# %% [markdown]
# **Gráfico de dispersion de ventas y regiones**

# %%
data['FechaVenta'] = pd.to_datetime(data['FechaVenta'], format='%d/%m/%Y', errors='coerce')
numeric_data = data.select_dtypes(include=['number'])
mapadecalor = sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm')
